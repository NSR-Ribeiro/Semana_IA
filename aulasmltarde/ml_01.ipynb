# %% [markdown]
# # Machine Learning: reconhecendo animais

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Papagaio José

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Galinha Pintadinha

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# | Imagem  | galinha_papagaio | tem bico | risco de extinção | faz cocoricó |
# |---------|------------------|----------|-------------------|--------------|
# | <img src="imagens/g1.png" width="100px"> | 1 | Sim | Não | Sim |
# | <img src="imagens/g2.png" width="100px"> | 0 | Sim | Sim | Não |
# | <img src="imagens/p3.png" width="100px"> | 1 | Sim | Não | Sim |
# | <img src="imagens/p2.jpg" width="100px"> | 0 | Sim | Sim | Não |
# |

# %% [markdown]
# | Imagem  | galinha_papagaio | tem bico | risco de extinção | faz cocoricó |
# |---------|------------------|----------|-------------------|--------------|
# | <img src="imagens/g1.png" width="100px"> | 1 | Sim | Não | Sim |
# | <img src="imagens/g2.png" width="100px"> | 0 | Sim | Sim | Não |
# | <img src="imagens/p3.png" width="100px"> | 1 | Sim | Não | Sim |
# | <img src="imagens/p2.jpg" width="100px"> | 0 | Sim | Sim | Não |
# | <img src="imagens/p4.jpg" width="100px"> | 1 | Sim | Não | Sim |
# | <img src="imagens/p1.jpg" width="100px"> | 1 | Sim | Não | Sim |

# %%
# Papagaio
# fatures [1 som, 0 nao]
# tembico?
# risco extinção?
# faz cocoricó?

papagaio1 = [1, 1, 0]
papagaio2 = [1, 1, 0]
papagaio3 = [1, 1, 1]
# Out:
# 3-element Vector{Int64}:
#  1
#  1
#  1

# %%
galinha1 = [1, 1, 1]
galinha2 = [1, 0, 1]
galinha3 = [1, 1, 1]
# Out:
# 3-element Vector{Int64}:
#  1
#  1
#  1

# %%
dados = [papagaio1, papagaio2, papagaio3, galinha1, galinha2, galinha3]
# Out:
# 6-element Vector{Vector{Int64}}:
#  [1, 1, 0]
#  [1, 1, 0]
#  [1, 1, 1]
#  [1, 1, 1]
#  [1, 0, 1]
#  [1, 1, 1]

# %%
dados = [papagaio1, papagaio2, papagaio3, galinha1, galinha2, galinha3]
classes = [1, 1, 1, 0, 0, 0,]
# Out:
# 6-element Vector{Int64}:
#  1
#  1
#  1
#  0
#  0
#  0

# %%
dados
# Out:
# 6-element Vector{Vector{Int64}}:
#  [1, 1, 0]
#  [1, 1, 0]
#  [1, 1, 1]
#  [1, 1, 1]
#  [1, 0, 1]
#  [1, 1, 1]

# %%
pip install scikit-learn
# Out:
# UndefVarError: `pip` not defined
