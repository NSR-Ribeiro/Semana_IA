# %%
! pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %% [markdown]
# -------------------------
# | Baixar o dataset |
# -------------------------

# %% [markdown]
# ---------------------------------------------------------------------
# | Passo 1: Importar bibliotecas e carregar o dataset |
# ---------------------------------------------------------------------

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
# Importando bibliotecas necessárias


import matplotlib.pyplot as plt

# Carregar o dataset
data = pd.read_csv("datasets/tracking.csv")  # Substitua pelo caminho correto do arquivo

# %% [markdown]
# -----------------------------------------------------------------
# | Passo 2: Análise Exploratória de Dados (EDA) |
# -----------------------------------------------------------------

# %%
# Visualizando as primeiras linhas do dataset
data.head()

# Informações gerais do dataset
data.info()

# Estatísticas descritivas
data.describe()

# Verificar valores nulos
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   inicial     99 non-null     int64
#  1   palestras   99 non-null     int64
#  2   contato     99 non-null     int64
#  3   comprou     99 non-null     int64
#  4   patrocinio  99 non-null     int64
# dtypes: int64(5)
# memory usage: 4.0 KB
# inicial       0
# palestras     0
# contato       0
# comprou       0
# patrocinio    0
# dtype: int64

# %% [markdown]
# ----------------------------------------------------------------------------
# | Passo 3: Identificar variáveis quantitativas e qualitativas|
# ----------------------------------------------------------------------------

# %%
# Identificar variáveis quantitativas
quantitative_vars = data.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Identificar variáveis qualitativas
qualitative_vars = data.select_dtypes(include=['object']).columns.tolist()
print("Variáveis Qualitativas:", qualitative_vars)
print("Variáveis quantitativas:", quantitative_vars)
# Out:
# Variáveis Qualitativas: []
# Variáveis quantitativas: ['inicial', 'palestras', 'contato', 'comprou', 'patrocinio']

# %%
# Criar uma tabela markdown explicando os tipos das variáveis
variaveis = quantitative_vars + qualitative_vars
tipos = ['Quantitativa'] * len(quantitative_vars) + ['Qualitativa'] * len(qualitative_vars)

# Encontrar o comprimento máximo para alinhamento
max_var_length = max([len(var) for var in variaveis])
max_type_length = max([len(tipo) for tipo in tipos])

# Criar a tabela formatada
tabela_markdown = f"| {'Variável'.ljust(max_var_length)} | {'Tipo'.ljust(max_type_length)} |\n"
tabela_markdown += f"| {'-' * max_var_length} | {'-' * max_type_length} |\n"

for var, tipo in zip(variaveis, tipos):
    tabela_markdown += f"| {var.ljust(max_var_length)} | {tipo.ljust(max_type_length)} |\n"

# Exibir a tabela
print(tabela_markdown)
# Out:
# | Variável   | Tipo         |
# | ---------- | ------------ |
# | inicial    | Quantitativa |
# | palestras  | Quantitativa |
# | contato    | Quantitativa |
# | comprou    | Quantitativa |
# | patrocinio | Quantitativa |

# %%
! pip install pandas numpy scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.1.1)
# Requirement already satisfied: scikit-learn in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\ead\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# Importação
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# Importar outros modelos e métricas conforme necessário

# %%
# Supondo que a última coluna seja o target
X = data.iloc[:, :-1]  # Features
y = data.iloc[:, -1]  # Target

# Verificando as dimensões (opcional)
print(X.shape)
print(y.shape)
# Out:
# (99, 4)
# (99,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
# Exemplo com um modelo de Regressão Logística
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Acurácia:", accuracy)
# Out:
# Acurácia: 1.0
