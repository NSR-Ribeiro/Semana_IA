# %% [markdown]
# <a href="https://colab.research.google.com/github/NSR-Ribeiro/Semana_IA/blob/master/aularegressaolinear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula Regressão Linear

# %% [markdown]
# ## Pré - Requisitos
#
#
#
# 1.   Par Ordenado e Plano Cartesiano
# 2.   Métodos dos Mínimos Quadrados
# 3.   Reta e Semireta
# 4.   Pandas (loc e iloc)
# 5.   Pandas (métodos básicos)
# 6.   Algoritmos

# %% [markdown]
# ## Carregar o DataSet

# %%
# Importando o pandas
import pandas as pd

# %%
# Variável url com endereço dodataset
url = 'https://raw.githubusercontent.com/romulosilvestre/regressaolinear_pf_2/refs/heads/main/tempo_salarios.csv'

# %%
df
# Out:
#     AnosdeExperiencia   Salario
# 0                 1.1   39343.0
# 1                 1.3   46205.0
# 2                 1.5   37731.0
# 3                 2.0   43525.0
# 4                 2.2   39891.0
# 5                 2.9   56642.0
# 6                 3.0   60150.0
# 7                 3.2   54445.0
# 8                 3.2   64445.0
# 9                 3.7   57189.0
# 10                3.9   63218.0
# 11                4.0   55794.0
# 12                4.0   56957.0
# 13                4.1   57081.0
# 14                4.5   61111.0
# 15                4.9   67938.0
# 16                5.1   66029.0
# 17                5.3   83088.0
# 18                5.9   81363.0
# 19                6.0   93940.0
# 20                6.8   91738.0
# 21                7.1   98273.0
# 22                7.9  101302.0
# 23                8.2  113812.0
# 24                8.7  109431.0
# 25                9.0  105582.0
# 26                9.5  116969.0
# 27                9.6  112635.0
# ...

# %%
# Carregar o dataset
df = pd.read_csv(url)

# %%
# Mostrar as colunas
df.columns
# Out:
# Index(['AnosdeExperiencia', 'Salario'], dtype='object')

# %% [markdown]
# ## Variável independente:
# # •	Anos de Experiência
# ## Variável dependente (quero prever)
# # •	Salário

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AnosdeExperiencia  30 non-null     float64
#  1   Salario            30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %% [markdown]
# # Tipos de Variáveis
# # •	Anos de Experiência: float, numérica, quantitativa contínua.
# # •	Salário: float, numérico, quantitativa contínua.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.head()
# Out:
#    AnosdeExperiencia  Salario
# 0                1.1  39343.0
# 1                1.3  46205.0
# 2                1.5  37731.0
# 3                2.0  43525.0
# 4                2.2  39891.0

# %%
df.describe()
# Out:
#        AnosdeExperiencia        Salario
# count          30.000000      30.000000
# mean            5.313333   76003.000000
# std             2.837888   27414.429785
# min             1.100000   37731.000000
# 25%             3.200000   56720.750000
# 50%             4.700000   65237.000000
# 75%             7.700000  100544.750000
# max            10.500000  122391.000000

# %% [markdown]
# ## Treino e Teste

# %%
X = X.reshape(-1,1)

# %% [markdown]
# ## Prepara os dados

# %%
X = df.iloc[:,0].values

# %%
x
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#         4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#         7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5])

# %%
print(f"Anos de Experiência:{x}")
# Out:
# Anos de Experiência:[ 1.1  1.3  1.5  2.   2.2  2.9  3.   3.2  3.2  3.7  3.9  4.   4.   4.1
#   4.5  4.9  5.1  5.3  5.9  6.   6.8  7.1  7.9  8.2  8.7  9.   9.5  9.6
#  10.3 10.5]

# %%
y = df.iloc[:,1].values

# %%
print(f"Salário:{y}")
# Out:
# Salário:[ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %% [markdown]
# # Separando os Dados (Treino e Teste)

# %%
# train_test_split: separa treino e teste(validação cruzada)
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Dados - x
# # Dados de treino - X_train
# # Dados de teste - X_test
# #-----------------------------------------------------
# # Classes (rótulos) - y

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
# Importar o algoritmo
from sklearn.linear_model import LinearRegression

# %%
# Regressor é um objeto da classe LinearRegression()
# O objeto vai chamar método (fit() predict())

regressor = LinearRegression()

# %%
# Treinando
X_train = X_train.reshape(-1, 1)
y_train = y_train.reshape(-1, 1)
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Sorria voçê estásendo treinado
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test = X_test.reshape(-1, 1)

# %%
y_pred = regressor.predict(X_test)

# %%
# Finalizando com o Gráfico
import matplotlib.pyplot as plt
# Visualizar os resultados de treino

# %%
plt.figure(figsize=(15,8))
plt.plot(X, y, 'Dr')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salário x Experiência ')
plt.xlabel('Anos de Experiência')
plt.ylabel('Salário')
plt.show()
